# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

# %%
data = pd.read_csv("ordinal.csv")

# %%
data.head()
# Out:
#    Id  Education Country
# 0   1        PhD     USA
# 1   2    Masters      UK
# 2   3  Bachelors  Canada
# 3   4        PhD     USA
# 4   5    Masters     USA

# %%
data["Education"].unique()
# Out:
# array(['PhD', 'Masters', 'Bachelors'], dtype=object)

# %%
data["Country"].unique()
# Out:
# array(['USA', 'UK', 'Canada'], dtype=object)

# %%
encoder= OrdinalEncoder()

# %%
encoder
# Out:
# OrdinalEncoder()

# %%
encoder.fit_transform(data[["Education"]])
# Out:
# array([[2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
# ...

# %%
data[["Education"]] =encoder.fit_transform(data[["Education"]])

# %%
data.head()
# Out:
#    Id  Education Country
# 0   1        2.0     USA
# 1   2        1.0      UK
# 2   3        0.0  Canada
# 3   4        2.0     USA
# 4   5        1.0     USA

# %%
education = ['PhD', 'Masters', 'Bachelors']

# %%
new = OrdinalEncoder(categories = [education])

# %%
new.fit_transform(data[["Education"]])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
# ...

# %%
data[["Education"]] =new.fit_transform(data[["Education"]])

# %%
print(data.head())
# Out:
#    Id  Education Country
# 0   1        0.0     USA
# 1   2        1.0      UK
# 2   3        2.0  Canada
# 3   4        0.0     USA
# 4   5        1.0     USA
